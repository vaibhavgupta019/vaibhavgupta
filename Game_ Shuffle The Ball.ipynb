# %%
# Get shuffle function from random library 
from random import shuffle

#Shuffling of list
def shuffle_list(my_list):
    shuffle(my_list)
    return my_list

#user guess input
def player_guess():
    guess= ''
   
    while guess not in ['0','1' ,'2']:
        guess = input("Please enter your guess from 0 , 1 or 2: ")
     
    return int(guess)  

#Checking Guess function 
def check_guess(mylist,guess):
    if mylist[guess] == 'O':
        print('Correct Guess!')
    else:
        print('Wrong! Better luck next time')
        print(mylist) 
         
if __name__ == '__main__':
 #Initialisation of list
  my_list = ['','O','']
  
 #invoking shuffle_list function  to randomly shuffle our list
  mixed_list= shuffle_list(my_list)

 #invoking player guess function to take user input
  guess= player_guess()

 #matching shuffled list and user guess to validate guess
  check_guess(mixed_list,guess)
# Out:
# Please enter your guess from 0 , 1 or 2:  2
# Wrong! Better luck next time
# ['O', '', '']
